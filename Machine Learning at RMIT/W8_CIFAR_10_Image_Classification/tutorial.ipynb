# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

## TODO
nbaDf = pd.read_csv(r"./CIFAR_Data.csv", delimiter=",")##, delimiter="\s+")
nbaDf.head()
# Out:
#                        ImgPath  Class
# 0  ./CIFAR_10_BATCH1/Img_0.png      6
# 1  ./CIFAR_10_BATCH1/Img_1.png      9
# 2  ./CIFAR_10_BATCH1/Img_2.png      9
# 3  ./CIFAR_10_BATCH1/Img_3.png      4
# 4  ./CIFAR_10_BATCH1/Img_4.png      1

# %%
nbaDf['Class'].unique()uherhe
# Out:
# array([6, 9, 4, 1, 2, 7, 8, 3, 5, 0])
